# %%
# Combine multiple images into one.
#
# To install the Pillow module on Mac OS X:
#
# $ xcode-select --install
# $ brew install libtiff libjpeg webp little-cms2
# $ pip install Pillow
#

from __future__ import print_function
import os

from PIL import Image

files = [
  'gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png','gg.png',
  'gg.png',
  'gg.png',
  'gg.png']

result = Image.new("RGB", (12800, 400))

for index, file in enumerate(files):
    path = os.path.expanduser(file)
    img = Image.open(path)
    img.thumbnail((400, 400), Image.ANTIALIAS)
    x = index * 400 
    y = index 
    w, h = img.size
    print('pos {0},{1} size {2},{3}'.format(x, y, w, h))
    result.paste(img, (x, y, x + w, y + h))

result.save(os.path.expanduser('image4.jpg'))
# Out:
# pos 0,0 size 400,400
# pos 400,1 size 400,400
# pos 800,2 size 400,400
# pos 1200,3 size 400,400
# pos 1600,4 size 400,400
# pos 2000,5 size 400,400
# pos 2400,6 size 400,400
# pos 2800,7 size 400,400
# pos 3200,8 size 400,400
# pos 3600,9 size 400,400
# pos 4000,10 size 400,400
# pos 4400,11 size 400,400
# pos 4800,12 size 400,400
# pos 5200,13 size 400,400
# pos 5600,14 size 400,400
# pos 6000,15 size 400,400
# pos 6400,16 size 400,400
# pos 6800,17 size 400,400
# pos 7200,18 size 400,400
# pos 7600,19 size 400,400
# pos 8000,20 size 400,400
# pos 8400,21 size 400,400
# pos 8800,22 size 400,400
# pos 9200,23 size 400,400
# pos 9600,24 size 400,400
# pos 10000,25 size 400,400
# pos 10400,26 size 400,400
# pos 10800,27 size 400,400
# pos 11200,28 size 400,400
# pos 11600,29 size 400,400
# pos 12000,30 size 400,400
# pos 12400,31 size 400,400
